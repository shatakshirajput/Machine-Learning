# %% [markdown]
# # Perceptron Implementation (Scratch)

# %%
import numpy as np

# %% [markdown]
# Step function (activation function)

# %%
def step_function(x):
    return 1 if x >= 0 else 0

# %% [markdown]
# Training data (AND Gate)

# %%
X = np.array([[0, 0],
              [0, 1],
              [1, 0],
              [1, 1]])
y = np.array([0, 0, 0, 1])

# %% [markdown]
# Initialise weights as bias

# %%
weights = np.zeros(2)
bias = 0

# %% [markdown]
# HyperParameters

# %%
learning_rate= 0.1
epochs = 10

# %% [markdown]
# Training Loop

# %%
for epoch in range(epochs):
    print(f"\nEpoch {epoch+1}")
    for i in range(len(X)):
        linear_output = np.dot(weights,X[i])+bias
        y_pred = step_function(linear_output)
        error = y[i] - y_pred
        weights = weights + learning_rate * error *X[i]
        bias = bias +learning_rate * error

        print(f"Input: {X[i]}, Pred: {y_pred}, Error: {error}")
# Out:
# Epoch 1
# Input: [0 0], Pred: 1, Error: -1
# Input: [0 1], Pred: 0, Error: 0
# Input: [1 0], Pred: 0, Error: 0
# Input: [1 1], Pred: 0, Error: 1
#
# Epoch 2
# Input: [0 0], Pred: 1, Error: -1
# Input: [0 1], Pred: 1, Error: -1
# Input: [1 0], Pred: 0, Error: 0
# Input: [1 1], Pred: 0, Error: 1
#
# Epoch 3
# Input: [0 0], Pred: 0, Error: 0
# Input: [0 1], Pred: 1, Error: -1
# Input: [1 0], Pred: 1, Error: -1
# Input: [1 1], Pred: 0, Error: 1
#
# Epoch 4
# Input: [0 0], Pred: 0, Error: 0
# Input: [0 1], Pred: 0, Error: 0
# Input: [1 0], Pred: 0, Error: 0
# Input: [1 1], Pred: 1, Error: 0
#
# Epoch 5
# Input: [0 0], Pred: 0, Error: 0
# Input: [0 1], Pred: 0, Error: 0
# Input: [1 0], Pred: 0, Error: 0
# Input: [1 1], Pred: 1, Error: 0
#
# Epoch 6
# Input: [0 0], Pred: 0, Error: 0
# Input: [0 1], Pred: 0, Error: 0
# Input: [1 0], Pred: 0, Error: 0
# Input: [1 1], Pred: 1, Error: 0
#
# Epoch 7
# Input: [0 0], Pred: 0, Error: 0
# Input: [0 1], Pred: 0, Error: 0
# ...

# %% [markdown]
# Final Weights and Bias

# %%
print("Trained Weights:", weights)
print("Trained Bias:", bias)
# Out:
# Trained Weights: [0.2 0.1]
# Trained Bias: -0.20000000000000004

# %% [markdown]
# Testing

# %%
for i in range(len(X)):
    linear_output = np.dot(weights, X[i]) + bias
    y_pred = step_function(linear_output)
    print(f"Input: {X[i]} -> Prediction: {y_pred}")
# Out:
# Input: [0 0] -> Prediction: 0
# Input: [0 1] -> Prediction: 0
# Input: [1 0] -> Prediction: 0
# Input: [1 1] -> Prediction: 1
